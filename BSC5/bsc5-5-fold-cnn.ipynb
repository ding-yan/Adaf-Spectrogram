# %%
# Import libraries
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
import torchvision.transforms as transforms
from sklearn.metrics import roc_auc_score, roc_curve
import pandas as pd
import numpy as np
from PIL import Image
import os
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from torch.optim.lr_scheduler import ReduceLROnPlateau
from torch.optim.lr_scheduler import StepLR
from torch.optim.lr_scheduler import CosineAnnealingLR

from sklearn.model_selection import StratifiedKFold  # Import for StratifiedKFold

# %%
# Device configuration
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
if torch.cuda.is_available():
    print(f"Using GPU: {torch.cuda.get_device_name(0)}")
else:
    print("Using CPU")
# Out:
# Using GPU: Tesla P100-PCIE-16GB

# %%
# 資料集路徑
# dataset_folder = '/kaggle/input/bsc5-spectrogramsamplitude/BSC5_Spectrograms(Amplitude)'
# dataset_folder = '/kaggle/input/bsc5-spectrogramspower/BSC5_Spectrograms(Power)'
# dataset_folder = '/kaggle/input/bsc5-spectrogramsdb/BSC5_Spectrograms(DB)'
#--------------------------------------------------------------------------------------------------------------
# dataset_folder = '/kaggle/input/bsc5-adaf-spectrograms-128amplitude/BSC5_Adaf_Spectrograms_128(Amplitude)'
# dataset_folder = '/kaggle/input/bsc5-adaf-spectrograms-128power/BSC5_Adaf_Spectrograms_128(Power)'
dataset_folder = '/kaggle/input/bsc5-adaf-spectrograms-128db/BSC5_Adaf_Spectrograms_128(DB)'
#--------------------------------------------------------------------------------------------------------------
# dataset_folder = '/kaggle/input/bsc5-mel-spectrograms-128/BSC5_Mel_Spectrograms_128'

# %%
import torchvision

class CNNModel(nn.Module):
  def __init__(self):
    super(CNNModel, self).__init__()
    self.net = torchvision.models.efficientnet_b0(weights = "DEFAULT")

      
    
    # 將預訓練的第一層權重平均，適配成單通道
    original_weights = self.net.features[0][0].weight.detach().clone()  # 取得原始權重
    new_weights = original_weights.mean(dim=1, keepdim=True)  # 計算平均權重
      
    # 修改 EfficientNet 的第一層卷積層，將輸入通道數從 3 改為 1
    self.net.features[0][0] = nn.Conv2d(1, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
    # self.net.features[0][0] = nn.Conv2d(1, 32, kernel_size=(128, 3), stride=(1, 1), padding=(0, 1), bias=False)
      
    self.net.features[0][0].weight = nn.Parameter(new_weights)  
    in_features = self.net.classifier[1].in_features 

    self.net.classifier = nn.Sequential(
            nn.Linear(in_features, 128),  
            nn.Dropout(0.3),
            nn.ReLU(),
            nn.Linear(128, 5),  
        )

  def forward(self, x):
    return self.net(x)

# %%
class SpectrogramDataset(Dataset):
    def __init__(self, image_paths, labels, transform=None):
        self.image_paths = image_paths
        self.labels = labels
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert('L')  # 轉為灰階
        label = self.labels[idx]
        if self.transform:
            image = self.transform(image)
        return image, label

# %%
# Data transformations
transform = transforms.Compose([
    transforms.Resize((128, 128)),  
    transforms.ToTensor()
])

# %%
# 掃描所有圖片路徑與標籤
all_images = []
all_labels = []
for file_name in os.listdir(dataset_folder):
    if file_name.endswith('.png'):
        img_path = os.path.join(dataset_folder, file_name)
        label = int(file_name.split('_')[0])
        all_images.append(img_path)
        all_labels.append(label)
        
all_images = np.array(all_images)
all_labels = np.array(all_labels)

# %%
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

# %%
# Store metrics for each fold
fold_train_losses = []
fold_val_losses = []
fold_train_accuracies = []
fold_val_accuracies = []
fold_auc_scores = []

# %%
for fold_idx, (train_idx, val_idx) in enumerate(skf.split(all_images, all_labels)):
    print(f"\n=== Fold {fold_idx + 1}/5 ===")
    # print("all_labels type:", type(all_labels))
    # print("all_labels[:5]:", all_labels[:5])
    # print("train_idx[:5]:", train_idx[:5])

    train_images, val_images = all_images[train_idx], all_images[val_idx]
    train_labels, val_labels = all_labels[train_idx], all_labels[val_idx]

    train_dataset = SpectrogramDataset(train_images, train_labels, transform=transform)
    val_dataset = SpectrogramDataset(val_images, val_labels, transform=transform)
    train_loader = DataLoader(train_dataset, batch_size=32, shuffle=True)
    val_loader = DataLoader(val_dataset, batch_size=32, shuffle=False)

    model = CNNModel().to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=0.001, weight_decay=1e-4)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=0.5, patience=3)

    num_epochs = 10
    train_losses = []
    val_losses = []
    train_accuracies = []
    val_accuracies = []
    auc_scores = []
    
    for epoch in range(num_epochs):
        model.train()
        train_loss = 0
        correct = 0
        total = 0

        for images, labels in train_loader:
            labels = labels.long().view(-1).to(device)
            images = images.to(device)

            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item()
            predicted = torch.argmax(outputs, dim=1)
            correct += (predicted == labels).sum().item()
            total += labels.size(0)

        train_accuracy = correct / total
        train_losses.append(train_loss / len(train_loader))
        train_accuracies.append(train_accuracy)

        # Validation
        model.eval()
        val_loss = 0
        correct = 0
        total = 0
        all_true = []
        all_probs = []

        with torch.no_grad():
            for images, labels in val_loader:
                labels = labels.long().view(-1).to(device)
                images = images.to(device)

                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item()

                predicted = torch.argmax(outputs, dim=1)
                correct += (predicted == labels).sum().item()
                total += labels.size(0)

                all_true.extend(labels.cpu().numpy())
                all_probs.extend(torch.nn.functional.softmax(outputs, dim=1).cpu().numpy())

        val_accuracy = correct / total
        val_losses.append(val_loss / len(val_loader))
        val_accuracies.append(val_accuracy)
        
        auc = roc_auc_score(all_true, all_probs, multi_class='ovo', average='macro')
        auc_scores.append(auc)
        scheduler.step(val_losses[-1])

        # Print metrics for each epoch
        print(f'Epoch {epoch + 1}/{num_epochs}, Train Loss: {train_losses[-1]:.4f}, Train Accuracy: {train_accuracies[-1]:.4f}, '
              f'Val Loss: {val_losses[-1]:.4f}, Val Accuracy: {val_accuracies[-1]:.4f}, AUC: {auc:.4f}, '
              f'Learning Rate: {optimizer.param_groups[0]["lr"]:.8f}')

     # 儲存當前 fold 訓練完成後的模型
    model_path = f'BSC-5_Adaf_Spectrograms_128(DB)_5fold_{fold_idx + 1}.pth'
    torch.save(model.state_dict(), model_path)
    print(f"--- Model for Fold {fold_idx + 1} saved to {model_path} ---")
    
    # Store final epoch metrics
    fold_train_losses.append(train_losses[-1])
    fold_val_losses.append(val_losses[-1])
    fold_train_accuracies.append(train_accuracies[-1])
    fold_val_accuracies.append(val_accuracies[-1])
    fold_auc_scores.append(auc_scores[-1])
# Out:
# === Fold 1/5 ===
# Downloading: "https://download.pytorch.org/models/efficientnet_b0_rwightman-7f5810bc.pth" to /root/.cache/torch/hub/checkpoints/efficientnet_b0_rwightman-7f5810bc.pth
# 100%|██████████| 20.5M/20.5M [00:00<00:00, 24.6MB/s]
# Epoch 1/10, Train Loss: 0.6515, Train Accuracy: 0.7731, Val Loss: 0.3058, Val Accuracy: 0.9014, AUC: 0.9869, Learning Rate: 0.00100000
# Epoch 2/10, Train Loss: 0.3028, Train Accuracy: 0.8985, Val Loss: 0.2062, Val Accuracy: 0.9253, AUC: 0.9944, Learning Rate: 0.00100000
# Epoch 3/10, Train Loss: 0.2453, Train Accuracy: 0.9188, Val Loss: 0.2474, Val Accuracy: 0.9207, AUC: 0.9919, Learning Rate: 0.00100000
# Epoch 4/10, Train Loss: 0.1824, Train Accuracy: 0.9444, Val Loss: 0.2117, Val Accuracy: 0.9382, AUC: 0.9948, Learning Rate: 0.00100000
# Epoch 5/10, Train Loss: 0.1575, Train Accuracy: 0.9470, Val Loss: 0.1493, Val Accuracy: 0.9558, AUC: 0.9964, Learning Rate: 0.00100000
# Epoch 6/10, Train Loss: 0.1399, Train Accuracy: 0.9553, Val Loss: 0.1945, Val Accuracy: 0.9346, AUC: 0.9953, Learning Rate: 0.00100000
# Epoch 7/10, Train Loss: 0.1067, Train Accuracy: 0.9631, Val Loss: 0.1397, Val Accuracy: 0.9650, AUC: 0.9967, Learning Rate: 0.00100000
# Epoch 8/10, Train Loss: 0.0976, Train Accuracy: 0.9673, Val Loss: 0.1507, Val Accuracy: 0.9521, AUC: 0.9976, Learning Rate: 0.00100000
# Epoch 9/10, Train Loss: 0.1044, Train Accuracy: 0.9682, Val Loss: 0.1734, Val Accuracy: 0.9539, AUC: 0.9959, Learning Rate: 0.00100000
# Epoch 10/10, Train Loss: 0.0668, Train Accuracy: 0.9767, Val Loss: 0.0779, Val Accuracy: 0.9760, AUC: 0.9991, Learning Rate: 0.00100000
# --- Model for Fold 1 saved to BSC-5_Adaf_Spectrograms_128(DB)_5fold_1.pth ---
#
# === Fold 2/5 ===
# Epoch 1/10, Train Loss: 0.6733, Train Accuracy: 0.7607, Val Loss: 0.3282, Val Accuracy: 0.8793, AUC: 0.9875, Learning Rate: 0.00100000
# Epoch 2/10, Train Loss: 0.3471, Train Accuracy: 0.8861, Val Loss: 0.2986, Val Accuracy: 0.9051, AUC: 0.9876, Learning Rate: 0.00100000
# Epoch 3/10, Train Loss: 0.2367, Train Accuracy: 0.9251, Val Loss: 0.2344, Val Accuracy: 0.9263, AUC: 0.9921, Learning Rate: 0.00100000
# Epoch 4/10, Train Loss: 0.2095, Train Accuracy: 0.9341, Val Loss: 0.2118, Val Accuracy: 0.9253, AUC: 0.9953, Learning Rate: 0.00100000
# Epoch 5/10, Train Loss: 0.1552, Train Accuracy: 0.9486, Val Loss: 0.1828, Val Accuracy: 0.9493, AUC: 0.9952, Learning Rate: 0.00100000
# Epoch 6/10, Train Loss: 0.1283, Train Accuracy: 0.9557, Val Loss: 0.1398, Val Accuracy: 0.9558, AUC: 0.9967, Learning Rate: 0.00100000
# Epoch 7/10, Train Loss: 0.1231, Train Accuracy: 0.9620, Val Loss: 0.1615, Val Accuracy: 0.9502, AUC: 0.9963, Learning Rate: 0.00100000
# Epoch 8/10, Train Loss: 0.1036, Train Accuracy: 0.9661, Val Loss: 0.2346, Val Accuracy: 0.9318, AUC: 0.9952, Learning Rate: 0.00100000
# Epoch 9/10, Train Loss: 0.0806, Train Accuracy: 0.9737, Val Loss: 0.2259, Val Accuracy: 0.9364, AUC: 0.9948, Learning Rate: 0.00100000
# Epoch 10/10, Train Loss: 0.0983, Train Accuracy: 0.9686, Val Loss: 0.2738, Val Accuracy: 0.9244, AUC: 0.9923, Learning Rate: 0.00050000
# --- Model for Fold 2 saved to BSC-5_Adaf_Spectrograms_128(DB)_5fold_2.pth ---
#
# === Fold 3/5 ===
# Epoch 1/10, Train Loss: 0.6668, Train Accuracy: 0.7649, Val Loss: 0.3283, Val Accuracy: 0.8875, AUC: 0.9873, Learning Rate: 0.00100000
# Epoch 2/10, Train Loss: 0.3255, Train Accuracy: 0.8914, Val Loss: 0.2725, Val Accuracy: 0.9114, AUC: 0.9906, Learning Rate: 0.00100000
# Epoch 3/10, Train Loss: 0.2408, Train Accuracy: 0.9142, Val Loss: 0.2572, Val Accuracy: 0.9197, AUC: 0.9913, Learning Rate: 0.00100000
# Epoch 4/10, Train Loss: 0.1828, Train Accuracy: 0.9398, Val Loss: 0.2096, Val Accuracy: 0.9391, AUC: 0.9947, Learning Rate: 0.00100000
# Epoch 5/10, Train Loss: 0.1366, Train Accuracy: 0.9557, Val Loss: 0.2050, Val Accuracy: 0.9419, AUC: 0.9946, Learning Rate: 0.00100000
# Epoch 6/10, Train Loss: 0.1066, Train Accuracy: 0.9666, Val Loss: 0.2327, Val Accuracy: 0.9437, AUC: 0.9922, Learning Rate: 0.00100000
# Epoch 7/10, Train Loss: 0.1189, Train Accuracy: 0.9613, Val Loss: 0.1964, Val Accuracy: 0.9446, AUC: 0.9950, Learning Rate: 0.00100000
# Epoch 8/10, Train Loss: 0.1060, Train Accuracy: 0.9647, Val Loss: 0.2042, Val Accuracy: 0.9465, AUC: 0.9954, Learning Rate: 0.00100000
# Epoch 9/10, Train Loss: 0.0920, Train Accuracy: 0.9710, Val Loss: 0.1646, Val Accuracy: 0.9483, AUC: 0.9964, Learning Rate: 0.00100000
# Epoch 10/10, Train Loss: 0.0731, Train Accuracy: 0.9760, Val Loss: 0.1374, Val Accuracy: 0.9585, AUC: 0.9974, Learning Rate: 0.00100000
# --- Model for Fold 3 saved to BSC-5_Adaf_Spectrograms_128(DB)_5fold_3.pth ---
#
# === Fold 4/5 ===
# Epoch 1/10, Train Loss: 0.6759, Train Accuracy: 0.7644, Val Loss: 0.3538, Val Accuracy: 0.8792, AUC: 0.9844, Learning Rate: 0.00100000
# Epoch 2/10, Train Loss: 0.3160, Train Accuracy: 0.8993, Val Loss: 0.4112, Val Accuracy: 0.8718, AUC: 0.9847, Learning Rate: 0.00100000
# Epoch 3/10, Train Loss: 0.2289, Train Accuracy: 0.9274, Val Loss: 0.2430, Val Accuracy: 0.9133, AUC: 0.9928, Learning Rate: 0.00100000
# Epoch 4/10, Train Loss: 0.1823, Train Accuracy: 0.9398, Val Loss: 0.2815, Val Accuracy: 0.9087, AUC: 0.9926, Learning Rate: 0.00100000
# Epoch 5/10, Train Loss: 0.1714, Train Accuracy: 0.9474, Val Loss: 0.2382, Val Accuracy: 0.9299, AUC: 0.9949, Learning Rate: 0.00100000
# Epoch 6/10, Train Loss: 0.1285, Train Accuracy: 0.9606, Val Loss: 0.2437, Val Accuracy: 0.9280, AUC: 0.9935, Learning Rate: 0.00100000
# Epoch 7/10, Train Loss: 0.0937, Train Accuracy: 0.9705, Val Loss: 0.2860, Val Accuracy: 0.9151, AUC: 0.9932, Learning Rate: 0.00100000
# Epoch 8/10, Train Loss: 0.1217, Train Accuracy: 0.9629, Val Loss: 0.2485, Val Accuracy: 0.9271, AUC: 0.9937, Learning Rate: 0.00100000
# Epoch 9/10, Train Loss: 0.1108, Train Accuracy: 0.9650, Val Loss: 0.3708, Val Accuracy: 0.8911, AUC: 0.9904, Learning Rate: 0.00050000
# Epoch 10/10, Train Loss: 0.0595, Train Accuracy: 0.9790, Val Loss: 0.1455, Val Accuracy: 0.9576, AUC: 0.9974, Learning Rate: 0.00050000
# --- Model for Fold 4 saved to BSC-5_Adaf_Spectrograms_128(DB)_5fold_4.pth ---
#
# === Fold 5/5 ===
# Epoch 1/10, Train Loss: 0.6649, Train Accuracy: 0.7582, Val Loss: 0.4447, Val Accuracy: 0.8552, AUC: 0.9756, Learning Rate: 0.00100000
# Epoch 2/10, Train Loss: 0.3227, Train Accuracy: 0.8926, Val Loss: 0.2948, Val Accuracy: 0.8985, AUC: 0.9886, Learning Rate: 0.00100000
# Epoch 3/10, Train Loss: 0.2353, Train Accuracy: 0.9198, Val Loss: 0.2486, Val Accuracy: 0.9114, AUC: 0.9928, Learning Rate: 0.00100000
# Epoch 4/10, Train Loss: 0.1994, Train Accuracy: 0.9378, Val Loss: 0.2256, Val Accuracy: 0.9345, AUC: 0.9934, Learning Rate: 0.00100000
# Epoch 5/10, Train Loss: 0.1573, Train Accuracy: 0.9479, Val Loss: 0.2148, Val Accuracy: 0.9317, AUC: 0.9940, Learning Rate: 0.00100000
# Epoch 6/10, Train Loss: 0.1119, Train Accuracy: 0.9620, Val Loss: 0.2901, Val Accuracy: 0.9151, AUC: 0.9926, Learning Rate: 0.00100000
# Epoch 7/10, Train Loss: 0.1035, Train Accuracy: 0.9684, Val Loss: 0.2518, Val Accuracy: 0.9317, AUC: 0.9934, Learning Rate: 0.00100000
# Epoch 8/10, Train Loss: 0.0910, Train Accuracy: 0.9710, Val Loss: 0.2342, Val Accuracy: 0.9373, AUC: 0.9941, Learning Rate: 0.00100000
# Epoch 9/10, Train Loss: 0.0905, Train Accuracy: 0.9730, Val Loss: 0.2742, Val Accuracy: 0.9216, AUC: 0.9950, Learning Rate: 0.00050000
# Epoch 10/10, Train Loss: 0.0308, Train Accuracy: 0.9915, Val Loss: 0.1753, Val Accuracy: 0.9613, AUC: 0.9968, Learning Rate: 0.00050000
# --- Model for Fold 5 saved to BSC-5_Adaf_Spectrograms_128(DB)_5fold_5.pth ---

# %%
mean_train_loss = np.mean(fold_train_losses)
std_train_loss = np.std(fold_train_losses)
mean_val_loss = np.mean(fold_val_losses)
std_val_loss = np.std(fold_val_losses)

mean_train_acc = np.mean(fold_train_accuracies)
std_train_acc = np.std(fold_train_accuracies)
mean_val_acc = np.mean(fold_val_accuracies)
std_val_acc = np.std(fold_val_accuracies)

mean_auc = np.mean(fold_auc_scores)
std_auc = np.std(fold_auc_scores)

# Print final results
print("Cross-Validation Results:")

print(f"Average Train Loss:     {mean_train_loss:.4f} ± {std_train_loss:.4f}")
print(f"Average Validation Loss:  {mean_val_loss:.4f} ± {std_val_loss:.4f}")

print(f"Average Train Accuracy:   {mean_train_acc*100:.2f} ± {std_train_acc*100:.2f} %")
print(f"Average Validation Acc:   {mean_val_acc*100:.2f} ± {std_val_acc*100:.2f} %")
print(f"Average Validation AUC:   {mean_auc:.2f} ± {std_auc:.2f}")
print(f"Average Validation AUC:   {mean_auc:} ± {std_auc:}")
# Out:
# Cross-Validation Results:
# Average Train Loss:     0.0657 ± 0.0218
# Average Validation Loss:  0.1620 ± 0.0642
# Average Train Accuracy:   97.84 ± 0.74 %
# Average Validation Acc:   95.56 ± 1.69 %
# Average Validation AUC:   1.00 ± 0.00
# Average Validation AUC:   0.9965879177072147 ± 0.0022660688500584208

# %%
# 計算訓練集各類別的張數
train_class_counts = {}
for _, label in train_dataset:
    train_class_counts[label] = train_class_counts.get(label, 0) + 1

# 印出各類別的張數
print("訓練集各類別的張數:")
for label, count in train_class_counts.items():
    print(f"類別 {label}: {count} 張")

# 計算測試集各類別的張數
test_class_counts = {}
for _, label in val_dataset:
    test_class_counts[label] = test_class_counts.get(label, 0) + 1

# 印出各類別的張數
print("測試集各類別的張數:")
for label, count in test_class_counts.items():
    print(f"類別 {label}: {count} 張")
# Out:
# 訓練集各類別的張數:
# 類別 1: 860 張
# 類別 4: 945 張
# 類別 0: 715 張
# 類別 3: 1004 張
# 類別 2: 814 張
# 測試集各類別的張數:
# 類別 2: 203 張
# 類別 3: 252 張
# 類別 1: 214 張
# 類別 0: 178 張
# 類別 4: 237 張

# %%
# Display
for i in range(5):
    image, _ = train_dataset[i]
    np_image = image.permute(1, 2, 0).numpy()
    plt.imshow(np_image)
    plt.title(f"Image {i+1}")
    plt.show()
